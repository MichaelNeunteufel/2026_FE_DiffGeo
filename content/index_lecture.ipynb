# %% [markdown]
# # Lecture "Finite Elements for Differential Geometry"
#
# The following notebooks are supplementary materials for the lecture. The current version of the script can be found [here](FE_DiffGeo_current.pdf).

# %% [markdown]
# ## Elasticity
# * [Linear elasticity](elasticity/linearelasticity.ipynb)
# * [Nonlinear elasticity](elasticity/nonlinearelasticity.ipynb)
# * [Nearly incompressible materials](elasticity/nearlyincompressibleelasticity.ipynb)
# * [Thin structures](elasticity/thin_structures.ipynb)
# * [TDNNS method for linear elasticity](elasticity/TDNNS_elasticity.ipynb)

# %% [markdown]
# ## Beams
# * [Euler-Bernoulli beams](beams/euler_bernoulli_beam.ipynb)
# * [Timoshenko beams](beams/timoshenko_beam_bc.ipynb)
# * [Shear locking in Timoshenko beams](beams/timoshenko_beam_locking.ipynb)
# * [Convergence 2D elasticity to beams](beams/convergence_2D_to_beam.ipynb)

# %% [markdown]
# ## Plates
#
# * [Reissner-Mindlin plate](plates/Reissner_Mindlin_plate.ipynb)
# * [Kirchhoff-Love plate](plates/Kirchhoff_Love_plate.ipynb)
# * [Boundary layers in Reissner-Mindlin plates](plates/Reissner_Mindlin_plate_boundarylayers.ipynb)
# * [Convergence 3D elasticity to plates](plates/convergence_3D_to_plate.ipynb)
# * [Relation HHJ and TDNNS for plates](plates/Relation_HHJ_TDNNS.ipynb)

# %% [markdown]
# ## Surfaces and Curvatures
#
# * [Surface Poisson equation](curvature/surface_poisson.ipynb)
# * [Curvature types](curvature/Curvature_types.ipynb)
# * [Discrete curvature approximation](curvature/discrete_extrinsic_curvature.ipynb)

# %% [markdown]
# ## Shells
#
# * [Nonlinear Koiter shell](shells/Koiter_shells_HHJ.ipynb)
# * [Kinked and branched shells](shells/Koiter_shell_kinks.ipynb)
# * [Regge elements for membrane locking](shells/Regge_elements_membranelocking.ipynb)
# * [Linear Koiter shell](shells/Linear_Koiter_Shell_HHJ.ipynb)
